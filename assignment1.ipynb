# %% [markdown]
# # **Task 1:**
#
# # Session 1
# # Assignment 1 Question
#
# 1.   Install Jupyter notebook and run the first program and share the screenshot of the output.
#
#
# [Local setup of jupiter ](https://drive.google.com/open?id=1c7CfeBxznugENM3Yd0kC9Ltk7HbOsKc2)
#
#
#
# 2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple
# of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
# comma-separated sequence on a single line.
# program and share the screenshot of the output.

# %%
# Program to iterate through a list using indexing
print("task2")

output_number = []

for num in range(1999, 3201):
    if (num % 7 == 0) and not (num % 5 == 0):
        output_number.append(str(num))
print(','.join(output_number))
# Out:
# task2
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# C:\Users\\AppData\Local\Programs\Python\Python37\python.exe C://123Ai/workspace/week2/assignmentweek2/question1.py
# task2
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199
#
# Process finished with exit code 0

# %% [markdown]
# 3.Write a Python program to accept the user's first and last name and then getting them printed in
# the the reverse order with a space between first name and last name.

# %%
# Program to iterate through a list using indexing
print("task3")

first_name = input("Enter your first name")
last_name = input("Enter your last name")

if len(first_name) > 0 and len(last_name) > 0:
    print("Your input details are \n " + last_name + ' ' + first_name)
else:
    print("Please enter valid inputs !!!")
# Out:
# task3
# Enter your first namename
# Enter your last namename3
# Your input details are
#  name3 name

# %% [markdown]
# 4 Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r 3

# %%
import math

print("volume of a sphere with diameter 12 cm")
volume_result=4/3 * math.pi * 12 **3
print("volume of a sphere with diameter 12 cm is equal to in cm = " +str(volume_result))
# Out:
# volume of a sphere with diameter 12 cm
# volume of a sphere with diameter 12 cm is equal to in cm = 7238.229473870882

# %% [markdown]
# # **Task 2:**
# 1.
# Write a program which accepts a sequence of comma-separated numbers from console and
# generate a list.
#
#
# **bold text**

# %%
print("Write a program which accepts a sequence of comma-separated numbers from console and generate a list")

inputsAsComma= input("Enter numbers with comma which will convert to list")
# Out:
# Write a program which accepts a sequence of comma-separated numbers from console and generate a list

# %% [markdown]
# 2.
# Create the below pattern using nested for loop in Python

# %%
print("Print pattern ")
for i in range(6):
    print(str("*") * i)
for i in range(6, -1, -1):
    print(str("*") * i)
# Out:
# Print pattern
#
# *
# **
# ***
# ****
# *****
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# 3.
# Write a Python program to reverse a word after accepting the input from the user.

# %%
print("Write a Python program to reverse a word after accepting the input from the user.")

word_input = input("Enter word ")

for char in range(len(word_input) - 1, -1, -1):
    print(word_input[char], end="D")

# %% [markdown]
# 4 .Write a Python Program to print the given string in the format specified in the sample output.
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
# SOVEREIGN,

# %%
print("WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens")

print("WE, THE PEOPLE OF INDIA,\n\t having solemnly resolved to constitute India into a SOVEREIGN,!\n\t\t\t SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n\t\t\t  and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
# WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN,!
# 			 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 			  and to secure to all its citizens
